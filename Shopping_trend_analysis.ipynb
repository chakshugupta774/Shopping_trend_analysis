# %% [markdown]
# # Identify Shopping Trends using Analysis

# %% [markdown]
# ### By : Chakshu Gupta

# %% [markdown]
# ### Import Python Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# ### Load Data as a DataFrame

# %%
shop = pd.read_csv('shopping_trends_updated.csv')
shop.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# ### Check the Number of Rows and Columns

# %%
shop.shape
# Out:
# (3900, 18)

# %% [markdown]
# ### Check DataFrame Information

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %% [markdown]
# ### Check the columns present in DataFrame

# %%
shop.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# ### Check the Null Values

# %%
shop.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# ### Check the Duplicate values

# %%
shop_dup = shop[shop.duplicated()]
shop_dup
# Out:
# Empty DataFrame
# Columns: [Customer ID, Age, Gender, Item Purchased, Category, Purchase Amount (USD), Location, Size, Color, Season, Review Rating, Subscription Status, Shipping Type, Discount Applied, Promo Code Used, Previous Purchases, Payment Method, Frequency of Purchases]
# Index: []

# %% [markdown]
# ### Check the minimum , maximuma and mean value of numeric columns

# %%
shop.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# #### Describe the Above Output
# - **Age** : In my data set, minimum age is 18 and maximum age is 70 . also Average age is 44

# %% [markdown]
# ### Check the Top and unique  value of each Category columns

# %%
shop.describe(include='object')
# Out:
#        Gender Item Purchased  Category Location  Size  Color  Season  \
# count    3900           3900      3900     3900  3900   3900    3900
# unique      2             25         4       50     4     25       4
# top      Male         Blouse  Clothing  Montana     M  Olive  Spring
# freq     2652            171      1737       96  1755    177     999
#
#        Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# count                 3900           3900             3900            3900
# unique                   2              6                2               2
# top                     No  Free Shipping               No              No
# freq                  2847            675             2223            2223
#
#        Payment Method Frequency of Purchases
# count            3900                   3900
# unique              6                      7
# top            PayPal         Every 3 Months
# freq              677                    584

# %% [markdown]
# ### Check Unique values of each of Category Columns

# %%
print("Gender : ",shop['Gender'].unique())
print("Item Purchased : ",shop['Item Purchased'].unique())
print("Category : ",shop['Category'].unique())
print("Location : ",shop['Location'].unique())
print("Size : ",shop['Size'].unique())
print("Color : ",shop['Color'].unique())
print("Season : ",shop['Season'].unique())
print("Subscription Status : ",shop['Subscription Status'].unique())
print("Shipping Type : ",shop['Shipping Type'].unique())
print("Discount Applied : ",shop['Discount Applied'].unique())
print("Promo Code Used : ",shop['Promo Code Used'].unique())
print("Payment Method : ",shop['Payment Method'].unique())
print("Frequency of Purchases : ",shop['Frequency of Purchases'].unique())
# Out:
# Gender :  ['Male' 'Female']
# Item Purchased :  ['Blouse' 'Sweater' 'Jeans' 'Sandals' 'Sneakers' 'Shirt' 'Shorts' 'Coat'
#  'Handbag' 'Shoes' 'Dress' 'Skirt' 'Sunglasses' 'Pants' 'Jacket' 'Hoodie'
#  'Jewelry' 'T-shirt' 'Scarf' 'Hat' 'Socks' 'Backpack' 'Belt' 'Boots'
#  'Gloves']
# Category :  ['Clothing' 'Footwear' 'Outerwear' 'Accessories']
# Location :  ['Kentucky' 'Maine' 'Massachusetts' 'Rhode Island' 'Oregon' 'Wyoming'
#  'Montana' 'Louisiana' 'West Virginia' 'Missouri' 'Arkansas' 'Hawaii'
#  'Delaware' 'New Hampshire' 'New York' 'Alabama' 'Mississippi'
#  'North Carolina' 'California' 'Oklahoma' 'Florida' 'Texas' 'Nevada'
#  'Kansas' 'Colorado' 'North Dakota' 'Illinois' 'Indiana' 'Arizona'
#  'Alaska' 'Tennessee' 'Ohio' 'New Jersey' 'Maryland' 'Vermont'
#  'New Mexico' 'South Carolina' 'Idaho' 'Pennsylvania' 'Connecticut' 'Utah'
#  'Virginia' 'Georgia' 'Nebraska' 'Iowa' 'South Dakota' 'Minnesota'
#  'Washington' 'Wisconsin' 'Michigan']
# Size :  ['L' 'S' 'M' 'XL']
# ...

# %% [markdown]
# ### Histogram of customers Age

# %%
sns.histplot(x='Age',data=shop)
plt.title('Histogram of Customers Age')
plt.xlabel("Age")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# ### Barplot of Gender

# %%
shop['Gender'].value_counts().plot(
    kind='bar',color=['orange','blue']
)
plt.title('Bar plot of customer Gender')
plt.xlabel('Gender')
plt.ylabel('Value Count')
plt.xticks(rotation = 0)
# Out:
# (array([0, 1]), [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %% [markdown]
# There seems to be more male customers than female customers in nearly 2;1 ratio

# %% [markdown]
# ### Purchased by  Category

# %% [markdown]
# Which category have the highest average purchase amount

# %%
hc = shop.groupby('Category')['Purchase Amount (USD)'].mean().sort_values(ascending=False)
hc
# Out:
# Category
# Footwear       60.255426
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# ### Distribution of Subscription Counts

# %%
shop['Subscription Status'].value_counts().plot(kind='pie',explode=(0,0.1),autopct='%1.1f%%',shadow=True)
plt.title("Distribuation of Subscription Counts")
plt.show()

# %% [markdown]
# Almost 73% of the Customers do not seem to be subscribed.

# %% [markdown]
# ### Distribution of Purchases by Category

# %%
shop["Category"].value_counts().plot(
        kind="pie",
        autopct='%1.1f%%',
        explode=(0.1, 0.1, 0.1, 0.1))
plt.title("Distribution of Purchases by Category")
plt.show()

# %% [markdown]
# Clothing seems to be purchased the most.
# and Outerwear seems to be purchased the least.

# %% [markdown]
# ### Puchased based on Locations

# %%
location_counts = shop['Location'].value_counts().head(10)
plt.figure(figsize=(10, 6))
location_counts.plot(kind='bar', color='purple')
plt.title('Top 10 Locations by Purchases')
plt.xlabel('Location')
plt.ylabel('Number of Purchases')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Item purchased per Season

# %%
sns.countplot(y='Size', hue='Category', data=shop, palette='viridis')
plt.title('Count Plot: Category vs. Season')
plt.xlabel('Count')
plt.ylabel('Category')
plt.legend(title='Season', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### Frequency of purchaase by number of customers

# %%
frequency_of_purchases_counts = shop['Frequency of Purchases'].value_counts()
plt.figure(figsize=(8, 6))
frequency_of_purchases_counts.plot(kind='bar', color='lightblue', edgecolor='black')
plt.title('Frequency of Purchases')
plt.xlabel('Frequency of Purchases')
plt.ylabel('Number of Customers')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Preferred Payment Methods

# %%
pd.DataFrame(shop["Payment Method"].value_counts().sort_values(ascending=False))
# Out:
#                 count
# Payment Method
# PayPal            677
# Credit Card       671
# Cash              670
# Debit Card        636
# Venmo             634
# Bank Transfer     612

# %% [markdown]
# PayPal and Credit Cards seem to be the most used, while Bank Transfers are relatively less common.

# %% [markdown]
# ### Total Amount purchased per item

# %%
px.histogram(shop,x='Item Purchased',color='Category')

# %% [markdown]
# ### Season bar plot

# %%
shop["Season"].value_counts().plot(
        kind="bar",color=['red','blue','green','yellow'])
plt.ylabel("Count")
plt.ylim(950,1010)
plt.show()

# %% [markdown]
# ### Customer Rating Tendency by Season

# %%
shop.groupby("Season")["Review Rating"].mean().round(1)
# Out:
# Season
# Fall      3.7
# Spring    3.8
# Summer    3.7
# Winter    3.8
# Name: Review Rating, dtype: float64

# %% [markdown]
# ### Purchase Amounts by Clothing Item Size

# %%
shop.groupby("Size")["Purchase Amount (USD)"].sum().apply(lambda x: np.round(x, 2)).sort_values(ascending=False)
# Out:
# Size
# M     105167
# L      61667
# S      40468
# XL     25779
# Name: Purchase Amount (USD), dtype: int32

# %% [markdown]
# ### Category by using Promo code

# %%
sns.countplot(data=shop,x='Category',hue='Promo Code Used')
# Out:
# <Axes: xlabel='Category', ylabel='count'>
